# %%
import struct
import numpy as np

def load_images(filepath):
    with open(filepath, 'rb') as f:
        magic, num, rows, cols = struct.unpack('>IIII', f.read(16))
        return np.frombuffer(f.read(), dtype=np.uint8).reshape(num, rows, cols)

def load_labels(filepath):
    with open(filepath, 'rb') as f:
        magic, num = struct.unpack('>II', f.read(8))
        return np.frombuffer(f.read(), dtype=np.uint8)

# Charger les 4 fichiers
x_train = load_images('/gzip/emnist-byclass-train-images-idx3-ubyte/emnist-byclass-train-images-idx3-ubyte')
y_train = load_labels('/gzip/emnist-byclass-train-labels-idx1-ubyte/emnist-byclass-train-labels-idx1-ubyte')

x_test  = load_images('/gzip/emnist-byclass-test-images-idx3-ubyte/emnist-byclass-test-images-idx3-ubyte')
y_test  = load_labels('/gzip/emnist-byclass-test-labels-idx1-ubyte/emnist-byclass-test-labels-idx1-ubyte')

print(f"Train : {x_train.shape}  →  {len(np.unique(y_train))} classes")
print(f"Test  : {x_test.shape}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\cleme\anaconda3\Lib\site-packages\scipy\io\matlab\_mio.py:39, in _open_file(file_like, appendmat, mode)
#      38 try:
# ---> 39     return open(file_like, mode), True
#      40 except OSError as e:
#      41     # Probably "not found"
#
# FileNotFoundError: [Errno 2] No such file or directory: '/gzip/gzip/emnist-byclass.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 5
#       2 import numpy as np
#       4 # Après extraction du .mat
# ----> 5 data = sio.loadmat('/gzip/gzip/emnist-byclass.mat')
#       6 x_train = data['dataset']['train'][0,0]['images'][0,0]
#       7 y_train = data['dataset']['train'][0,0]['labels'][0,0]
#
# File c:\Users\cleme\anaconda3\Lib\site-packages\scipy\io\matlab\_mio.py:233, in loadmat(file_name, mdict, appendmat, spmatrix, **kwargs)
#      88 """
#      89 Load MATLAB file.
#      90
#    (...)    230     3.14159265+3.14159265j])
#     231 """
#     232 variable_names = kwargs.pop('variable_names', None)
# --> 233 with _open_file_context(file_name, appendmat) as f:
#     234     MR, _ = mat_reader_factory(f, **kwargs)
#     235     matfile_dict = MR.get_variables(variable_names)
#
# File c:\Users\cleme\anaconda3\Lib\contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\cleme\anaconda3\Lib\site-packages\scipy\io\matlab\_mio.py:17, in _open_file_context(file_like, appendmat, mode)
#      15 @contextmanager
#      16 def _open_file_context(file_like, appendmat, mode='rb'):
# ---> 17     f, opened = _open_file(file_like, appendmat, mode)
#      18     try:
#      19         yield f
#
# File c:\Users\cleme\anaconda3\Lib\site-packages\scipy\io\matlab\_mio.py:45, in _open_file(file_like, appendmat, mode)
#      43     if appendmat and not file_like.endswith('.mat'):
#      44         file_like += '.mat'
# ---> 45     return open(file_like, mode), True
#      46 else:
#      47     raise OSError(
#      48         'Reader needs file name or open file-like object'
#      49     ) from e
#
# FileNotFoundError: [Errno 2] No such file or directory: '/gzip/gzip/emnist-byclass.mat'
