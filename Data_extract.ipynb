# %%
import struct
import numpy as np

def load_images(filepath):
    with open(filepath, 'rb') as f:
        magic, num, rows, cols = struct.unpack('>IIII', f.read(16))
        return np.frombuffer(f.read(), dtype=np.uint8).reshape(num, rows, cols)

def load_labels(filepath):
    with open(filepath, 'rb') as f:
        magic, num = struct.unpack('>II', f.read(8))
        return np.frombuffer(f.read(), dtype=np.uint8)

# Charger les 4 fichiers
x_train = load_images('gzip\emnist-byclass-train-images-idx3-ubyte\emnist-byclass-train-images-idx3-ubyte')
y_train = load_labels('gzip\emnist-byclass-train-labels-idx1-ubyte\emnist-byclass-train-labels-idx1-ubyte')

x_test  = load_images('gzip\emnist-byclass-test-images-idx3-ubyte\emnist-byclass-test-images-idx3-ubyte')
y_test  = load_labels('gzip\emnist-byclass-test-labels-idx1-ubyte\emnist-byclass-test-labels-idx1-ubyte')

print(f"Train : {x_train.shape}  →  {len(np.unique(y_train))} classes")
print(f"Test  : {x_test.shape}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 15
#      12         return np.frombuffer(f.read(), dtype=np.uint8)
#      14 # Charger les 4 fichiers
# ---> 15 x_train = load_images('\gzip\emnist-byclass-train-images-idx3-ubyte\emnist-byclass-train-images-idx3-ubyte')
#      16 y_train = load_labels('\gzip\emnist-byclass-train-labels-idx1-ubyte\emnist-byclass-train-labels-idx1-ubyte')
#      18 x_test  = load_images('\gzip\emnist-byclass-test-images-idx3-ubyte\emnist-byclass-test-images-idx3-ubyte')
#
# Cell In[2], line 5, in load_images(filepath)
#       4 def load_images(filepath):
# ----> 5     with open(filepath, 'rb') as f:
#       6         magic, num, rows, cols = struct.unpack('>IIII', f.read(16))
#       7         return np.frombuffer(f.read(), dtype=np.uint8).reshape(num, rows, cols)
#
# File c:\Users\cleme\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\gzip\\emnist-byclass-train-images-idx3-ubyte\\emnist-byclass-train-images-idx3-ubyte'
